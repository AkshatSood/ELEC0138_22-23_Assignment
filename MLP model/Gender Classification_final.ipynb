# %%
import pandas as pd
import numpy as np
import os
import tqdm
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping
from sklearn.model_selection import train_test_split

import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("balanced-all.csv")
df.head()
# Out:
#                                 filename  gender
# 0  data/cv-other-train/sample-069205.npy  female
# 1  data/cv-valid-train/sample-063134.npy  female
# 2  data/cv-other-train/sample-080873.npy  female
# 3  data/cv-other-train/sample-105595.npy  female
# 4  data/cv-valid-train/sample-144613.npy  female

# %%
# get total samples
n_samples = len(df)
# get total male samples
n_male_samples = len(df[df['gender'] == 'male'])
# get total female samples
n_female_samples = len(df[df['gender'] == 'female'])
print("Total samples:", n_samples)
print("Total male samples:", n_male_samples)
print("Total female samples:", n_female_samples)
# Out:
# Total samples: 66938
# Total male samples: 33469
# Total female samples: 33469

# %%
label2int = {
    "male": 1,
    "female": 0
}

def load_data(vector_length=128):
    """A function to load gender recognition dataset from `data` folder
    After the second run, this will load from results/features.npy and results/labels.npy files
    as it is much faster!"""
    # make sure results folder exists
    if not os.path.isdir("results"):
        os.mkdir("results")
    # if features & labels already loaded individually and bundled, load them from there instead
    if os.path.isfile("results/features.npy") and os.path.isfile("results/labels.npy"):
        X = np.load("results/features.npy")
        y = np.load("results/labels.npy")
        return X, y
    # read dataframe
    df = pd.read_csv("balanced-all.csv")
    # get total samples
    n_samples = len(df)
    # get total male samples
    n_male_samples = len(df[df['gender'] == 'male'])
    # get total female samples
    n_female_samples = len(df[df['gender'] == 'female'])
    print("Total samples:", n_samples)
    print("Total male samples:", n_male_samples)
    print("Total female samples:", n_female_samples)
    # initialize an empty array for all audio features
    X = np.zeros((n_samples, vector_length))
    # initialize an empty array for all audio labels (1 for male and 0 for female)
    y = np.zeros((n_samples, 1))
    for i, (filename, gender) in tqdm.tqdm(enumerate(zip(df['filename'], df['gender'])), "Loading data", total=n_samples):
        features = np.load(filename)
        X[i] = features
        y[i] = label2int[gender]
    # save the audio features and labels into files
    # so we won't load each one of them next run
    np.save("results/features", X)
    np.save("results/labels", y)
    return X, y

# %%
def split_data(X, y, test_size=0.1, valid_size=0.1):
    # split training set and testing set
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=7)
    # split training set and validation set
    X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=valid_size, random_state=7)
    # return a dictionary of values
    return {
        "X_train": X_train,
        "X_valid": X_valid,
        "X_test": X_test,
        "y_train": y_train,
        "y_valid": y_valid,
        "y_test": y_test
    }

# %%
# load the dataset
X, y = load_data()
# split the data into training, validation and testing sets
data = split_data(X, y, test_size=0.1, valid_size=0.1)

# %%
from tensorflow import keras
from tensorflow.keras import layers
from kerastuner import HyperParameters
import tensorflow as tf

def build_model(hp,vector_length=128):
    drop_out_rate = hp.Float('dropout_rate', 0.2, 0.5,0.1)
    model = Sequential()
    model.add(layers.Dense(units=hp.Int('units_input', 32, 512, 32),
                               input_shape=(vector_length,),
                               activation=hp.Choice('activation_input', ['relu','tanh','sigmoid']
                               )))
    model.add(Dropout(drop_out_rate))
    
    for i in range(hp.Int('num_layers_dense', 1, 5, 1)):
        model.add(Dense(units=hp.Int(f"units_dense_{i}", 32, 512, 32),
                              activation=hp.Choice(f"activation_dense_{i}", [ 'relu','tanh','sigmoid'])))
        model.add(Dropout(drop_out_rate))

    model.add(layers.Dense(1,activation="sigmoid"))

    model.compile(optimizer=hp.Choice('optimizer', ['adam', 'rmsprop']),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model
# Out:
# C:\Users\ntyzx\AppData\Local\Temp\ipykernel_20732\2213948802.py:3: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner import HyperParameters

# %%
from kerastuner import RandomSearch

tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,
    executions_per_trial=1,
    directory='my_dir',
    overwrite=True,
    project_name='helloworld')

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, verbose=1)

# %%
tuner.search(data["X_train"], data["y_train"],epochs=50,validation_data=(data["X_valid"], data["y_valid"]), callbacks=[stop_early])
# Out:
# Trial 10 Complete [00h 03m 45s]
# val_accuracy: 0.9268049597740173
#
# Best val_accuracy So Far: 0.9415767788887024
# Total elapsed time: 00h 46m 55s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in my_dir\helloworld
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x000001C853FEA310>
# Trial summary
# Hyperparameters:
# dropout_rate: 0.2
# units_input: 288
# activation_input: relu
# num_layers_dense: 3
# units_dense_0: 192
# activation_dense_0: tanh
# optimizer: adam
# units_dense_1: 288
# activation_dense_1: relu
# units_dense_2: 32
# activation_dense_2: relu
# Score: 0.9415767788887024
# Trial summary
# Hyperparameters:
# dropout_rate: 0.30000000000000004
# units_input: 448
# activation_input: relu
# num_layers_dense: 4
# units_dense_0: 288
# activation_dense_0: tanh
# optimizer: adam
# units_dense_1: 224
# activation_dense_1: sigmoid
# units_dense_2: 224
# activation_dense_2: tanh
# units_dense_3: 320
# activation_dense_3: tanh
# Score: 0.940248966217041
# Trial summary
# Hyperparameters:
# dropout_rate: 0.2
# units_input: 352
# activation_input: tanh
# num_layers_dense: 1
# units_dense_0: 384
# activation_dense_0: sigmoid
# optimizer: adam
# units_dense_1: 320
# activation_dense_1: relu
# units_dense_2: 96
# activation_dense_2: tanh
# units_dense_3: 64
# activation_dense_3: sigmoid
# Score: 0.9377593398094177
# Trial summary
# Hyperparameters:
# dropout_rate: 0.30000000000000004
# units_input: 128
# activation_input: tanh
# num_layers_dense: 3
# units_dense_0: 128
# activation_dense_0: relu
# optimizer: adam
# units_dense_1: 288
# activation_dense_1: relu
# units_dense_2: 416
# activation_dense_2: tanh
# Score: 0.9327800869941711
# Trial summary
# Hyperparameters:
# dropout_rate: 0.30000000000000004
# units_input: 288
# activation_input: relu
# num_layers_dense: 3
# units_dense_0: 512
# activation_dense_0: tanh
# optimizer: rmsprop
# units_dense_1: 224
# activation_dense_1: relu
# units_dense_2: 416
# activation_dense_2: tanh
# Score: 0.9319502115249634
# Trial summary
# Hyperparameters:
# dropout_rate: 0.4
# units_input: 256
# activation_input: relu
# num_layers_dense: 2
# units_dense_0: 352
# activation_dense_0: tanh
# optimizer: rmsprop
# units_dense_1: 32
# activation_dense_1: relu
# Score: 0.9282987713813782
# Trial summary
# Hyperparameters:
# dropout_rate: 0.2
# units_input: 320
# activation_input: tanh
# num_layers_dense: 4
# units_dense_0: 128
# activation_dense_0: tanh
# optimizer: rmsprop
# units_dense_1: 256
# activation_dense_1: relu
# units_dense_2: 96
# activation_dense_2: sigmoid
# units_dense_3: 352
# activation_dense_3: sigmoid
# Score: 0.9281327724456787
# Trial summary
# Hyperparameters:
# dropout_rate: 0.30000000000000004
# units_input: 352
# activation_input: tanh
# num_layers_dense: 3
# units_dense_0: 160
# activation_dense_0: relu
# optimizer: rmsprop
# units_dense_1: 320
# activation_dense_1: tanh
# units_dense_2: 256
# activation_dense_2: tanh
# units_dense_3: 384
# activation_dense_3: relu
# Score: 0.9268049597740173
# Trial summary
# Hyperparameters:
# dropout_rate: 0.2
# units_input: 32
# activation_input: tanh
# num_layers_dense: 4
# units_dense_0: 256
# activation_dense_0: relu
# optimizer: rmsprop
# units_dense_1: 96
# activation_dense_1: relu
# units_dense_2: 256
# activation_dense_2: relu
# units_dense_3: 32
# activation_dense_3: relu
# Score: 0.9198340177536011
# Trial summary
# Hyperparameters:
# dropout_rate: 0.4
# units_input: 288
# activation_input: sigmoid
# num_layers_dense: 3
# units_dense_0: 224
# activation_dense_0: sigmoid
# optimizer: rmsprop
# units_dense_1: 32
# activation_dense_1: tanh
# units_dense_2: 160
# activation_dense_2: sigmoid
# units_dense_3: 512
# activation_dense_3: tanh
# Score: 0.91651451587677

# %%
# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=10)[0]

# %%
# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
model = tuner.hypermodel.build(best_hps)
history = model.fit(data["X_train"], data["y_train"], epochs=50, validation_data=(data["X_valid"], data["y_valid"]))

val_acc_per_epoch = history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Epoch 1/50
# 1695/1695 [==============================] - 6s 3ms/step - loss: 0.3629 - accuracy: 0.8491 - val_loss: 0.2776 - val_accuracy: 0.8870
# Epoch 2/50
# 1695/1695 [==============================] - 6s 3ms/step - loss: 0.2849 - accuracy: 0.8885 - val_loss: 0.2414 - val_accuracy: 0.9087
# Epoch 3/50
# 1695/1695 [==============================] - 6s 4ms/step - loss: 0.2553 - accuracy: 0.9030 - val_loss: 0.2394 - val_accuracy: 0.9069
# Epoch 4/50
# 1695/1695 [==============================] - 8s 5ms/step - loss: 0.2363 - accuracy: 0.9089 - val_loss: 0.2409 - val_accuracy: 0.9102
# Epoch 5/50
# 1695/1695 [==============================] - 8s 5ms/step - loss: 0.2249 - accuracy: 0.9156 - val_loss: 0.2126 - val_accuracy: 0.9207
# Epoch 6/50
# 1695/1695 [==============================] - 8s 5ms/step - loss: 0.2144 - accuracy: 0.9187 - val_loss: 0.2096 - val_accuracy: 0.9217
# Epoch 7/50
# 1695/1695 [==============================] - 8s 5ms/step - loss: 0.2071 - accuracy: 0.9224 - val_loss: 0.1968 - val_accuracy: 0.9261
# Epoch 8/50
# 1695/1695 [==============================] - 8s 4ms/step - loss: 0.2011 - accuracy: 0.9255 - val_loss: 0.2066 - val_accuracy: 0.9256
# Epoch 9/50
# 1695/1695 [==============================] - 7s 4ms/step - loss: 0.1953 - accuracy: 0.9272 - val_loss: 0.1959 - val_accuracy: 0.9293
# Epoch 10/50
# 1695/1695 [==============================] - 8s 4ms/step - loss: 0.1905 - accuracy: 0.9290 - val_loss: 0.1912 - val_accuracy: 0.9329
# Epoch 11/50
# 1695/1695 [==============================] - 8s 4ms/step - loss: 0.1859 - accuracy: 0.9311 - val_loss: 0.1902 - val_accuracy: 0.9283
# Epoch 12/50
# 1695/1695 [==============================] - 8s 5ms/step - loss: 0.1817 - accuracy: 0.9316 - val_loss: 0.1943 - val_accuracy: 0.9320
# Epoch 13/50
# 1695/1695 [==============================] - 8s 5ms/step - loss: 0.1797 - accuracy: 0.9334 - val_loss: 0.1909 - val_accuracy: 0.9328
# Epoch 14/50
# 1695/1695 [==============================] - 8s 5ms/step - loss: 0.1756 - accuracy: 0.9348 - val_loss: 0.1883 - val_accuracy: 0.9338
# Epoch 15/50
# 1695/1695 [==============================] - 8s 5ms/step - loss: 0.1733 - accuracy: 0.9365 - val_loss: 0.1931 - val_accuracy: 0.9321
# Epoch 16/50
# 1695/1695 [==============================] - 8s 5ms/step - loss: 0.1681 - accuracy: 0.9381 - val_loss: 0.1926 - val_accuracy: 0.9306
# Epoch 17/50
# 1695/1695 [==============================] - 8s 5ms/step - loss: 0.1633 - accuracy: 0.9390 - val_loss: 0.1816 - val_accuracy: 0.9354
# Epoch 18/50
# 1695/1695 [==============================] - 8s 5ms/step - loss: 0.1620 - accuracy: 0.9397 - val_loss: 0.1837 - val_accuracy: 0.9368
# Epoch 19/50
# 1695/1695 [==============================] - 8s 5ms/step - loss: 0.1613 - accuracy: 0.9399 - val_loss: 0.1873 - val_accuracy: 0.9334
# Epoch 20/50
# 1695/1695 [==============================] - 6s 4ms/step - loss: 0.1581 - accuracy: 0.9401 - val_loss: 0.1991 - val_accuracy: 0.9346
# Epoch 21/50
# 1695/1695 [==============================] - 6s 4ms/step - loss: 0.1569 - accuracy: 0.9419 - val_loss: 0.1999 - val_accuracy: 0.9301
# Epoch 22/50
# 1695/1695 [==============================] - 6s 4ms/step - loss: 0.1546 - accuracy: 0.9418 - val_loss: 0.1841 - val_accuracy: 0.9363
# Epoch 23/50
# 1695/1695 [==============================] - 7s 4ms/step - loss: 0.1504 - accuracy: 0.9444 - val_loss: 0.1855 - val_accuracy: 0.9378
# Epoch 24/50
# 1695/1695 [==============================] - 7s 4ms/step - loss: 0.1525 - accuracy: 0.9435 - val_loss: 0.1902 - val_accuracy: 0.9376
# Epoch 25/50
# 1695/1695 [==============================] - 7s 4ms/step - loss: 0.1477 - accuracy: 0.9451 - val_loss: 0.1785 - val_accuracy: 0.9376
# Epoch 26/50
# 1695/1695 [==============================] - 8s 5ms/step - loss: 0.1457 - accuracy: 0.9470 - val_loss: 0.1778 - val_accuracy: 0.9364
# Epoch 27/50
# 1695/1695 [==============================] - 8s 5ms/step - loss: 0.1480 - accuracy: 0.9451 - val_loss: 0.1960 - val_accuracy: 0.9381
# Epoch 28/50
# 1695/1695 [==============================] - 8s 5ms/step - loss: 0.1434 - accuracy: 0.9459 - val_loss: 0.1889 - val_accuracy: 0.9366
# Epoch 29/50
# 1695/1695 [==============================] - 8s 5ms/step - loss: 0.1433 - accuracy: 0.9477 - val_loss: 0.1848 - val_accuracy: 0.9391
# Epoch 30/50
# 1695/1695 [==============================] - 8s 5ms/step - loss: 0.1414 - accuracy: 0.9477 - val_loss: 0.1905 - val_accuracy: 0.9391
# Epoch 31/50
# 1695/1695 [==============================] - 8s 5ms/step - loss: 0.1405 - accuracy: 0.9494 - val_loss: 0.1827 - val_accuracy: 0.9393
# Epoch 32/50
# 1695/1695 [==============================] - 8s 5ms/step - loss: 0.1391 - accuracy: 0.9496 - val_loss: 0.1890 - val_accuracy: 0.9412
# Epoch 33/50
# 1695/1695 [==============================] - 7s 4ms/step - loss: 0.1386 - accuracy: 0.9497 - val_loss: 0.1906 - val_accuracy: 0.9389
# Epoch 34/50
# 1695/1695 [==============================] - 5s 3ms/step - loss: 0.1371 - accuracy: 0.9499 - val_loss: 0.2079 - val_accuracy: 0.9376
# Epoch 35/50
# 1695/1695 [==============================] - 5s 3ms/step - loss: 0.1355 - accuracy: 0.9499 - val_loss: 0.2063 - val_accuracy: 0.9376
# Epoch 36/50
# 1695/1695 [==============================] - 5s 3ms/step - loss: 0.1333 - accuracy: 0.9511 - val_loss: 0.1987 - val_accuracy: 0.9396
# Epoch 37/50
# 1695/1695 [==============================] - 6s 3ms/step - loss: 0.1318 - accuracy: 0.9524 - val_loss: 0.1836 - val_accuracy: 0.9396
# Epoch 38/50
# 1695/1695 [==============================] - 6s 3ms/step - loss: 0.1329 - accuracy: 0.9513 - val_loss: 0.2013 - val_accuracy: 0.9378
# Epoch 39/50
# 1695/1695 [==============================] - 5s 3ms/step - loss: 0.1317 - accuracy: 0.9512 - val_loss: 0.1849 - val_accuracy: 0.9417
# Epoch 40/50
# 1695/1695 [==============================] - 5s 3ms/step - loss: 0.1292 - accuracy: 0.9535 - val_loss: 0.1866 - val_accuracy: 0.9421
# Epoch 41/50
# 1695/1695 [==============================] - 6s 3ms/step - loss: 0.1296 - accuracy: 0.9524 - val_loss: 0.1885 - val_accuracy: 0.9394
# Epoch 42/50
# 1695/1695 [==============================] - 5s 3ms/step - loss: 0.1291 - accuracy: 0.9536 - val_loss: 0.1878 - val_accuracy: 0.9371
# Epoch 43/50
# 1695/1695 [==============================] - 5s 3ms/step - loss: 0.1257 - accuracy: 0.9533 - val_loss: 0.1869 - val_accuracy: 0.9409
# Epoch 44/50
# 1695/1695 [==============================] - 5s 3ms/step - loss: 0.1260 - accuracy: 0.9539 - val_loss: 0.1960 - val_accuracy: 0.9411
# Epoch 45/50
# 1695/1695 [==============================] - 5s 3ms/step - loss: 0.1236 - accuracy: 0.9547 - val_loss: 0.1871 - val_accuracy: 0.9416
# Epoch 46/50
# 1695/1695 [==============================] - 6s 3ms/step - loss: 0.1247 - accuracy: 0.9541 - val_loss: 0.1777 - val_accuracy: 0.9396
# Epoch 47/50
# 1695/1695 [==============================] - 7s 4ms/step - loss: 0.1262 - accuracy: 0.9543 - val_loss: 0.1899 - val_accuracy: 0.9414
# Epoch 48/50
# 1695/1695 [==============================] - 7s 4ms/step - loss: 0.1228 - accuracy: 0.9554 - val_loss: 0.1855 - val_accuracy: 0.9441
# Epoch 49/50
# 1695/1695 [==============================] - 6s 4ms/step - loss: 0.1209 - accuracy: 0.9558 - val_loss: 0.1807 - val_accuracy: 0.9406
# Epoch 50/50
# 1695/1695 [==============================] - 6s 4ms/step - loss: 0.1189 - accuracy: 0.9574 - val_loss: 0.1981 - val_accuracy: 0.9386
# Best epoch: 48

# %%
hypermodel = tuner.hypermodel.build(best_hps)

# Retrain the model
hypermodel.fit(data["X_train"], data["y_train"], epochs=best_epoch, validation_split=0.2)
# Out:
# Epoch 1/30
# 1356/1356 [==============================] - 7s 4ms/step - loss: 0.3757 - accuracy: 0.8412 - val_loss: 0.3169 - val_accuracy: 0.8828
# Epoch 2/30
# 1356/1356 [==============================] - 6s 4ms/step - loss: 0.2964 - accuracy: 0.8823 - val_loss: 0.2685 - val_accuracy: 0.8916
# Epoch 3/30
# 1356/1356 [==============================] - 6s 4ms/step - loss: 0.2683 - accuracy: 0.8961 - val_loss: 0.2409 - val_accuracy: 0.9078
# Epoch 4/30
# 1356/1356 [==============================] - 6s 4ms/step - loss: 0.2470 - accuracy: 0.9049 - val_loss: 0.2261 - val_accuracy: 0.9126
# Epoch 5/30
# 1356/1356 [==============================] - 6s 4ms/step - loss: 0.2337 - accuracy: 0.9120 - val_loss: 0.2233 - val_accuracy: 0.9136
# Epoch 6/30
# 1356/1356 [==============================] - 6s 4ms/step - loss: 0.2224 - accuracy: 0.9177 - val_loss: 0.2136 - val_accuracy: 0.9183
# Epoch 7/30
# 1356/1356 [==============================] - 6s 4ms/step - loss: 0.2139 - accuracy: 0.9195 - val_loss: 0.2096 - val_accuracy: 0.9223
# Epoch 8/30
# 1356/1356 [==============================] - 5s 4ms/step - loss: 0.2053 - accuracy: 0.9231 - val_loss: 0.2025 - val_accuracy: 0.9215
# Epoch 9/30
# 1356/1356 [==============================] - 6s 4ms/step - loss: 0.1979 - accuracy: 0.9254 - val_loss: 0.2065 - val_accuracy: 0.9199
# Epoch 10/30
# 1356/1356 [==============================] - 6s 4ms/step - loss: 0.1958 - accuracy: 0.9271 - val_loss: 0.2004 - val_accuracy: 0.9256
# Epoch 11/30
# 1356/1356 [==============================] - 5s 4ms/step - loss: 0.1873 - accuracy: 0.9299 - val_loss: 0.1982 - val_accuracy: 0.9258
# Epoch 12/30
# 1356/1356 [==============================] - 4s 3ms/step - loss: 0.1846 - accuracy: 0.9305 - val_loss: 0.1994 - val_accuracy: 0.9252
# Epoch 13/30
# 1356/1356 [==============================] - 4s 3ms/step - loss: 0.1797 - accuracy: 0.9317 - val_loss: 0.2085 - val_accuracy: 0.9275
# Epoch 14/30
# 1356/1356 [==============================] - 4s 3ms/step - loss: 0.1792 - accuracy: 0.9323 - val_loss: 0.1929 - val_accuracy: 0.9313
# Epoch 15/30
# 1356/1356 [==============================] - 5s 4ms/step - loss: 0.1713 - accuracy: 0.9366 - val_loss: 0.1985 - val_accuracy: 0.9279
# Epoch 16/30
# 1356/1356 [==============================] - 4s 3ms/step - loss: 0.1699 - accuracy: 0.9368 - val_loss: 0.1943 - val_accuracy: 0.9277
# Epoch 17/30
# 1356/1356 [==============================] - 5s 4ms/step - loss: 0.1682 - accuracy: 0.9378 - val_loss: 0.2277 - val_accuracy: 0.9187
# Epoch 18/30
# 1356/1356 [==============================] - 6s 4ms/step - loss: 0.1639 - accuracy: 0.9390 - val_loss: 0.1957 - val_accuracy: 0.9331
# Epoch 19/30
# 1356/1356 [==============================] - 5s 4ms/step - loss: 0.1616 - accuracy: 0.9399 - val_loss: 0.1924 - val_accuracy: 0.9307
# Epoch 20/30
# 1356/1356 [==============================] - 5s 3ms/step - loss: 0.1620 - accuracy: 0.9399 - val_loss: 0.1944 - val_accuracy: 0.9291
# Epoch 21/30
# 1356/1356 [==============================] - 5s 4ms/step - loss: 0.1566 - accuracy: 0.9416 - val_loss: 0.2132 - val_accuracy: 0.9292
# Epoch 22/30
# 1356/1356 [==============================] - 4s 3ms/step - loss: 0.1557 - accuracy: 0.9432 - val_loss: 0.1984 - val_accuracy: 0.9312
# Epoch 23/30
# 1356/1356 [==============================] - 5s 4ms/step - loss: 0.1541 - accuracy: 0.9436 - val_loss: 0.2017 - val_accuracy: 0.9279
# Epoch 24/30
# 1356/1356 [==============================] - 6s 4ms/step - loss: 0.1502 - accuracy: 0.9442 - val_loss: 0.2119 - val_accuracy: 0.9297
# Epoch 25/30
# 1356/1356 [==============================] - 5s 4ms/step - loss: 0.1472 - accuracy: 0.9447 - val_loss: 0.1926 - val_accuracy: 0.9308
# Epoch 26/30
# 1356/1356 [==============================] - 5s 4ms/step - loss: 0.1492 - accuracy: 0.9454 - val_loss: 0.1995 - val_accuracy: 0.9311
# Epoch 27/30
# 1356/1356 [==============================] - 6s 4ms/step - loss: 0.1472 - accuracy: 0.9458 - val_loss: 0.2045 - val_accuracy: 0.9310
# Epoch 28/30
# 1356/1356 [==============================] - 5s 4ms/step - loss: 0.1458 - accuracy: 0.9455 - val_loss: 0.2019 - val_accuracy: 0.9315
# Epoch 29/30
# 1356/1356 [==============================] - 5s 4ms/step - loss: 0.1426 - accuracy: 0.9472 - val_loss: 0.1919 - val_accuracy: 0.9330
# Epoch 30/30
# 1356/1356 [==============================] - 5s 4ms/step - loss: 0.1411 - accuracy: 0.9480 - val_loss: 0.1981 - val_accuracy: 0.9347

# %%
eval_result = hypermodel.evaluate(data["X_train"], data["y_train"])
print("[test loss, test accuracy]:", eval_result)
# Out:
# 1695/1695 [==============================] - 2s 1ms/step - loss: 0.1223 - accuracy: 0.9555
# [test loss, test accuracy]: [0.12227419018745422, 0.955495297908783]

# %%
# test

# %%
import numpy
p = numpy.load('sample-000005.npy');
# print(p)

# predict the gender!
male_prob = model.predict(p.reshape(1,-1))[0][0]
female_prob = 1 - male_prob
gender = "male" if male_prob > female_prob else "female"
# show the result!
print("Result:", gender)
print(f"Probabilities::: Male: {male_prob*100:.2f}%    Female: {female_prob*100:.2f}%")
# Out:
# 1/1 [==============================] - 0s 79ms/step
# Result: male
# Probabilities::: Male: 99.64%    Female: 0.36%

# %%
def extract_feature(file_name, **kwargs):
    """
    Extract feature from audio file `file_name`
        Features supported:
            - MFCC (mfcc)
            - Chroma (chroma)
            - MEL Spectrogram Frequency (mel)
            - Contrast (contrast)
            - Tonnetz (tonnetz)
        e.g:
        `features = extract_feature(path, mel=True, mfcc=True)`
    """
    mfcc = kwargs.get("mfcc")
    chroma = kwargs.get("chroma")
    mel = kwargs.get("mel")
    contrast = kwargs.get("contrast")
    tonnetz = kwargs.get("tonnetz")
    X, sample_rate = librosa.core.load(file_name)
    if chroma or contrast:
        stft = np.abs(librosa.stft(X))
    result = np.array([])
    if mfcc:
        mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
        result = np.hstack((result, mfccs))
    if chroma:
        chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
        result = np.hstack((result, chroma))
    if mel:
        mel = np.mean(librosa.feature.melspectrogram(y=X, sr=sample_rate).T,axis=0)
        result = np.hstack((result, mel))
    if contrast:
        contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)
        result = np.hstack((result, contrast))
    if tonnetz:
        tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X), sr=sample_rate).T,axis=0)
        result = np.hstack((result, tonnetz))
    return result

# %%
# import numpy
# h=extract_feature('test_data_before_masking/male/5639-40744-0008.flac',mel=True)
# print(len(h))
# # predict the gender!
# male_prob = model.predict(h.reshape(1,-1))[0][0]
# female_prob = 1 - male_prob
# gender = "male" if male_prob > female_prob else "female"
# # show the result!
# print("Result:", gender)
# print(f"Probabilities::: Male: {male_prob*100:.2f}%    Female: {female_prob*100:.2f}%")

# %%
import os
import csv
import re

def read_text_gt(datapath):
    
    gt_path = os.path.join(datapath, "SPEAKERS.TXT")
    with open(gt_path, 'r') as file:
        lines = file.readlines()
    speaker_dict = {}
    for num, line in enumerate(lines):
        if num<12:
            continue
        items = line.strip().split(' ')
        key = items[0]
        gender = next((char for char in line if char in ["F", "M"]), None)
        speaker_dict[key] = gender

    audio_dict = {}
    for root, dirs, files in os.walk(datapath):
        for file in files:
            if file.endswith('.flac'):
                key = file.split('-')[0].split('_')[-1]
                audio_dict[os.path.join(root, file)]=speaker_dict[key]
    
    return audio_dict

# %%
a=read_text_gt(r'C:\Users\ntyzx\Security and Privacy\test-clean\LibriSpeech',)

# test-clean without masking
male_1 = {}
female_1 = {}
for k, v in a.items():
    if v == 'M':
        male_1[k] = v
    elif v == 'F':
        female_1[k] = v
print(len(male_1))
print(len(female_1))
      
# get all keys
keys_male_1 = male_1.keys()
keys_female_1 = female_1.keys()

# keys to list
key_list_male_1 = list(keys_male_1)
key_list_female_1 = list(keys_female_1)

# print list
print(len(key_list_male_1))  
print(len(key_list_female_1))

# %%
b=read_text_gt(r'C:\Users\ntyzx\Security and Privacy\dev-clean\LibriSpeech',)

# dev-clean without masking
male_2 = {}
female_2 = {}
for k, v in b.items():
    if v == 'M':
        male_2[k] = v
    elif v == 'F':
        female_2[k] = v
print(len(male_2))
print(len(female_2))
      
# get all keys
keys_male_2 = male_2.keys()
keys_female_2 = female_2.keys()

# keys to list
key_list_male_2 = list(keys_male_2)
key_list_female_2 = list(keys_female_2)

# print list
print(len(key_list_male_2))  
print(len(key_list_female_2))

# %%
#combine two data set into one lists
male_1_2 = key_list_male_1+key_list_male_2
female_1_2 = key_list_female_1+key_list_female_2
print(len(male_1_2))
print(len(female_1_2))

# %%
h_male =[]
male_prob =[]
female_prob =[]
gender_male=[]
for i in range(len(male_1_2)):
    h_male.append(extract_feature(male_1_2[i], mel=True))

    # predict the gender!
    male_prob.append(model.predict(h_male[i].reshape(1,-1))[0][0])

    female_prob.append(1 - male_prob[i])
    gender_male.append("male" if male_prob[i] > female_prob[i] else "female")

count_of_male = gender_male.count('male')
print("Number of 'male' in the list:", count_of_male)

# %%
h_female =[]
male_prob =[]
female_prob =[]
gender_female=[]
for i in range(len(male_1_2)):
    h_female.append(extract_feature(female_1_2[i], mel=True))

    # predict the gender!
    male_prob.append(loaded_model.predict(h_female[i].reshape(1,-1))[0][0])

    female_prob.append(1 - male_prob[i])
    gender_female.append("male" if male_prob[i] > female_prob[i] else "female")

count_of_female = gender_female.count('female')
print("Number of 'female' in the list:", count_of_female)

# %%
####################################################################################################################

# %%
c=read_text_gt(r'C:\Users\ntyzx\Security and Privacy\test-clean_1\LibriSpeech',)

# test-clean with masking
male_3 = {}
female_3 = {}
for k, v in c.items():
    if v == 'M':
        male_3[k] = v
    elif v == 'F':
        female_3[k] = v
print(len(male_3))
print(len(female_3))
      
# get all keys
keys_male_3 = male_3.keys()
keys_female_3 = female_3.keys()

# keys to list
key_list_male_3 = list(keys_male_3)
key_list_female_3 = list(keys_female_3)

# print list
print(len(key_list_male_3))  
print(len(key_list_female_3))

# %%
d=read_text_gt(r'C:\Users\ntyzx\Security and Privacy\dev-clean_2\LibriSpeech',)

# dev-clean without masking
male_4 = {}
female_4 = {}
for k, v in d.items():
    if v == 'M':
        male_4[k] = v
    elif v == 'F':
        female_4[k] = v
print(len(male_4))
print(len(female_4))
      
# get all keys
keys_male_4 = male_4.keys()
keys_female_4 = female_4.keys()

# keys to list
key_list_male_4 = list(keys_male_4)
key_list_female_4 = list(keys_female_4)

# print list
print(len(key_list_male_4))  
print(len(key_list_female_4))

# %%
#combine two data set into one lists
male_3_4 = key_list_male_3+key_list_male_4
female_3_4 = key_list_female_3+key_list_female_4
print(len(male_3_4))
print(len(female_3_4))

# %%
h_male_2 =[]
male_prob =[]
female_prob =[]
gender_male_2=[]
for i in range(len(male_3_4)):
    h_male_2.append(extract_feature(male_3_4[i], mel=True))

    # predict the gender!
    male_prob.append(model.predict(h_male_2[i].reshape(1,-1))[0][0])

    female_prob.append(1 - male_prob[i])
    gender_male_2.append("male" if male_prob[i] > female_prob[i] else "female")

count_of_male = gender_female.count('male')
print("Number of 'male' in the list:", count_of_male)

# %%
h_female_2 =[]
male_prob =[]
female_prob =[]
gender_female_2=[]
for i in range(len(male_3_4)):
    h_female_2.append(extract_feature(female_3_4[i], mel=True))

    # predict the gender!
    male_prob.append(model.predict(h_female_2[i].reshape(1,-1))[0][0])

    female_prob.append(1 - male_prob[i])
    gender_female_2.append("male" if male_prob[i] > female_prob[i] else "female")

print(gender_female_2)

count_of_female = gender_female_2.count('female')
print("Number of 'female' in the list:", count_of_female)
